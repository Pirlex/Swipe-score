# %% [markdown]
# # Stock News Analysis with AI Scoring (Amazon Bedrock)
#
# This notebook:
# 1. Fetches news for a stock ticker from Yahoo Finance (last 3 months) using defeatbeta-api
# 2. Uses Amazon Bedrock AI to select the most interesting news items
# 3. Fetches full content using defeatbeta-api
# 4. Scores each news item on multiple criteria using Amazon Bedrock

# %% [markdown]
# ## 1. Install Required Libraries

# %%
# !pip install defeatbeta-api boto3 matplotlib pandas -q

# %% [markdown]
# ## 2. Import Libraries

# %%
import boto3
import json
import os
from datetime import datetime, timedelta
import pandas as pd
from typing import List, Dict, Any
import time
import numpy as np
import matplotlib.pyplot as plt

# Import defeatbeta-api
from defeatbeta_api.data.ticker import Ticker

# %% [markdown]
# ## 3. Configuration

# %%
# Configuration
STOCK_TICKER = "AAPL"  # Change this to your desired stock ticker
TOP_N_NEWS = 10  # Number of most interesting news to analyze
MONTHS_BACK = 3  # How many months of news to fetch

# AWS Bedrock Configuration
AWS_REGION = os.environ.get("AWS_REGION", "us-east-1")  # Change to your preferred region
BEDROCK_MODEL_ID = "anthropic.claude-3-5-sonnet-20241022-v2:0"  # Claude 3.5 Sonnet

# Initialize Bedrock client
bedrock_runtime = boto3.client(
    service_name='bedrock-runtime',
    region_name=AWS_REGION
)

print(f"Using Amazon Bedrock in region: {AWS_REGION}")
print(f"Model: {BEDROCK_MODEL_ID}")
print(f"Analyzing stock: {STOCK_TICKER}")
# Out:
# Using Amazon Bedrock in region: us-west-2
# Model: anthropic.claude-3-5-sonnet-20241022-v2:0
# Analyzing stock: AAPL

# %% [markdown]
# ## 4. Bedrock Helper Functions

# %%
def invoke_bedrock_model(prompt: str, max_tokens: int = 2000) -> str:
    """
    Invoke Amazon Bedrock model with a prompt.
    
    Args:
        prompt: The prompt to send to the model
        max_tokens: Maximum tokens in response
    
    Returns:
        Model response text
    """
    # Prepare the request body for Claude 3.5 Sonnet
    body = json.dumps({
        "anthropic_version": "bedrock-2023-05-31",
        "max_tokens": max_tokens,
        "messages": [
            {
                "role": "user",
                "content": prompt
            }
        ],
        "temperature": 0.7,
        "top_p": 0.9
    })
    
    try:
        # Invoke the model
        response = bedrock_runtime.invoke_model(
            modelId=BEDROCK_MODEL_ID,
            body=body
        )
        
        # Parse response
        response_body = json.loads(response['body'].read())
        return response_body['content'][0]['text']
    
    except Exception as e:
        print(f"Error invoking Bedrock: {e}")
        raise

# %% [markdown]
# ## 5. Fetch News from DefeatBeta API

# %%
def get_stock_news(ticker_symbol: str, months_back: int = 3) -> List[Dict[str, Any]]:
    """
    Fetch news for a given ticker using defeatbeta-api.
    
    Args:
        ticker_symbol: Stock ticker symbol
        months_back: Number of months to look back
    
    Returns:
        List of news items with title, content, publisher, and timestamp
    """
    print(f"Fetching news for {ticker_symbol}...")
    
    # Initialize ticker
    ticker = Ticker(ticker_symbol)
    
    # Get news data
    news_data = ticker.news()
    
    # Get the news list as DataFrame
    news_df = news_data.get_news_list()
    
    if news_df is None or len(news_df) == 0:
        print("No news found for this ticker")
        return []
    
    # Filter news from last N months
    cutoff_date = datetime.now() - timedelta(days=months_back * 30)
    
    filtered_news = []
    for _, row in news_df.iterrows():
        try:
            # Parse the report date
            report_date = pd.to_datetime(row['report_date'])

            if report_date >= cutoff_date:
                news_item = {
                    'uuid': row['uuid'],
                    'title': row['title'],
                    'publisher': row['publisher'],
                    'report_date': report_date.strftime('%Y-%m-%d'),
                    'link': row['link'],
                    'content': ''  # Will be populated later
                }
                filtered_news.append(news_item)
        except Exception as e:
            print(f"Error processing news item: {e}")
            continue
    
    print(f"Found {len(filtered_news)} news items from the last {months_back} months")
    return filtered_news

# %%
# Fetch news
# news_items = get_stock_news(STOCK_TICKER, months_back=MONTHS_BACK)

# # Display sample
# print("\nSample news items:")
# for i, item in enumerate(news_items[:3]):
#     print(f"\n{i+1}. {item['title']}")
#     print(f"   Publisher: {item['publisher']}")
#     print(f"   Date: {item['report_date']}")
#     print(f"   Link: {item['link'][:80]}..." if len(item['link']) > 80 else f"   Link: {item['link']}")
# Out:
# Fetching news for AAPL...
# Found 894 news items from the last 3 months
#
# Sample news items:
#
# 1. IBN Initiates Coverage of Wearable Devices Ltd. (NASDAQ: WLDS)
#    Publisher: GlobeNewswire
#    Date: 2025-08-05
#    Link: https://finance.yahoo.com/news/ibn-initiates-coverage-wearable-devices-123000448...
#
# 2. Palantir’s Ultra-Expensive Valuation Sparks Worry Into Results
#    Publisher: Bloomberg
#    Date: 2025-08-05
#    Link: https://finance.yahoo.com/news/palantir-ultra-expensive-valuation-sparks-1030007...
#
# 3. 1 S&P 500 Stock to Target This Week and 2 We Find Risky
#    Publisher: StockStory
#    Date: 2025-08-05
#    Link: https://finance.yahoo.com/news/1-p-500-stock-target-043406147.html

# %% [markdown]
# ## 6. AI Selection of Most Interesting News

# %%
def select_interesting_news(news_items: List[Dict], ticker: str, top_n: int = 10) -> List[Dict]:
    """
    Use Amazon Bedrock AI to select the most interesting news items.
    
    Args:
        news_items: List of news items
        ticker: Stock ticker symbol
        top_n: Number of top news to select
    
    Returns:
        List of selected news items with rankings
    """
    if len(news_items) == 0:
        return []
    
    print(f"\nUsing Amazon Bedrock AI to select top {top_n} most interesting news items...")
    
    # Prepare news list for AI
    news_list_text = "\n".join([
        f"{i+1}. [{item['report_date']}] {item['title']} (Publisher: {item['publisher']})"
        for i, item in enumerate(news_items)
    ])
    
    prompt = f"""You are a financial analyst tasked with selecting the most interesting and impactful news about {ticker}.

Here are the news items:

{news_list_text}

Please analyze these news items and select the top {min(top_n, len(news_items))} most interesting ones based on:
- Potential impact on stock price
- Relevance to company fundamentals
- Newsworthiness and significance
- Market-moving potential

Return ONLY a JSON array with the indices (1-based) of the selected news items in order of importance, like this:
[1, 5, 3, 8, 2, 12, 7, 9, 4, 11]

No explanations, just the JSON array."""
    
    try:
        response_text = invoke_bedrock_model(prompt, max_tokens=500)
        
        # Parse response
        content = response_text.strip()
        # Extract JSON array from response
        if '[' in content and ']' in content:
            start = content.index('[')
            end = content.rindex(']') + 1
            content = content[start:end]
        
        selected_indices = json.loads(content)
        
        # Get selected news items
        selected_news = [news_items[idx - 1] for idx in selected_indices if 0 < idx <= len(news_items)]
        
        print(f"Selected {len(selected_news)} news items")
        return selected_news[:top_n]
    
    except Exception as e:
        print(f"Error selecting news: {e}")
        print("Returning first {top_n} items as fallback")
        return news_items[:top_n]

# %%
# Select interesting news
# interesting_news = select_interesting_news(news_items, STOCK_TICKER, top_n=TOP_N_NEWS)

# print("\nSelected interesting news:")
# for i, item in enumerate(interesting_news):
#     print(f"\n{i+1}. {item['title']}")
#     print(f"   Date: {item['report_date']}")
# Out:
# Using Amazon Bedrock AI to select top 10 most interesting news items...
# Selected 10 news items
#
# Selected interesting news:
#
# 1. Apple Jumps 5.1% After $100 Billion U.S. Manufacturing Pledge
#    Date: 2025-08-07
#
# 2. Apple announces additional $100 billion in US investment, following Trump iPhone tariff threat
#    Date: 2025-08-07
#
# 3. Apple Raises US Investment to $600 Billion as Trump Eyes 100% Chip Tariffs
#    Date: 2025-08-07
#
# 4. Apple Announces $100 Billion US Investment Ahead of Trump Event
#    Date: 2025-08-07
#
# 5. Apple Stock Rallies on Trump’s Plan for ‘Make in America’ Tariff Exemptions
#    Date: 2025-08-08
#
# 6. Apple's $600 Billion U.S. Investment Could Reshape Its Future
#    Date: 2025-08-10
#
# 7. Apple announces five-year partnership as U.S. broadcast partner for Formula 1
#    Date: 2025-10-18
#
# 8. Apple (AAPL) Q4 Earnings and Revenues Beat Estimates
#    Date: 2025-10-31
#
# 9. Market Chatter: Globalstar Explores Sale, Holds Early Talks With SpaceX
#    Date: 2025-10-31
#
# 10. Heard on the Street Recap: Market Streak
#    Date: 2025-11-01

# %% [markdown]
# ## 7. Fetch Full Content from DefeatBeta API

# %%
def fetch_news_content(ticker_symbol: str, news_items: List[Dict]) -> List[Dict]:
    """
    Fetch full content for all news items using defeatbeta-api.
    
    Args:
        ticker_symbol: Stock ticker symbol
        news_items: List of news items with UUIDs
    
    Returns:
        List of news items with full content added
    """
    print("\nFetching full content for selected news...")
    
    # Initialize ticker
    ticker = Ticker(ticker_symbol)
    news_api = ticker.news()
    
    for i, item in enumerate(news_items):
        print(f"Fetching content {i+1}/{len(news_items)}...")
        try:
            # Get full news content using UUID
            news_detail = news_api.get_news(item['uuid'])
            
            if news_detail is not None and not news_detail.empty:
                # Extract content from the DataFrame
                content = news_detail.iloc[0]['content'] if 'content' in news_detail.columns else ''
                item['content'] = content if content else item['title']
            else:
                item['content'] = item['title']  # Fallback to title if no content
                
        except Exception as e:
            print(f"Error fetching content for item {i+1}: {e}")
            item['content'] = item['title']  # Fallback to title
        
        time.sleep(0.5)  # Rate limiting
    
    print("Content fetching complete!")
    return news_items

# %%
# Fetch full content
# news_with_content = fetch_news_content(STOCK_TICKER, interesting_news)

# # Display sample content
# print("\nSample content preview:")
# if len(news_with_content) > 0 and news_with_content[0]['content']:
#     print(f"Title: {news_with_content[0]['title']}")
#     print(f"Content preview: {news_with_content[0]['content'][:300]}...")
# else:
#     print("No content available for first item")
# Out:
# Fetching full content for selected news...
# Fetching content 1/10...
# Fetching content 2/10...
# Fetching content 3/10...
# Fetching content 4/10...
# Fetching content 5/10...
# Fetching content 6/10...
# Fetching content 7/10...
# Fetching content 8/10...
# Fetching content 9/10...
# Fetching content 10/10...
# Content fetching complete!
#
# Sample content preview:
# Title: Apple Jumps 5.1% After $100 Billion U.S. Manufacturing Pledge
# Content preview: Apple Jumps 5.1% After $100 Billion U.S. Manufacturing Pledge...

# %% [markdown]
# ## 8. AI Scoring of News Items

# %%
def score_news_item(news_item: Dict, ticker: str) -> Dict:
    """
    Score a news item on multiple criteria using Amazon Bedrock AI.
    
    Args:
        news_item: News item with title, content, etc.
        ticker: Stock ticker symbol
    
    Returns:
        Dictionary with scores and explanation
    """
    content_text = news_item['content'] if news_item['content'] else news_item['title']
    
    prompt = f"""You are a financial analyst scoring news about {ticker}.

News Title: {news_item['title']}
Published: {news_item['report_date']}
Publisher: {news_item['publisher']}

Content:
{content_text[:3000]}

Please analyze this news and score it on the following criteria (0-10 scale):

1. SENTIMENT SCORE (0-10):
   - 0 = Very negative for stock
   - 5 = Neutral
   - 10 = Very positive for stock

2. LIKELIHOOD SCORE (0-10):
   - 0 = Pure speculation/rumor
   - 5 = Possible/probable
   - 10 = Already happened/100% certain

3. IMPACT SCORE (0-10):
   - 0 = No impact on stock price
   - 5 = Moderate impact
   - 10 = Major impact on stock price

Return ONLY a JSON object with this exact structure:
{{
  "sentiment_score": <number>,
  "likelihood_score": <number>,
  "impact_score": <number>,
  "explanation": "<brief 2-3 sentence explanation of the scores>"
}}

No other text, just the JSON object."""
    
    try:
        response_text = invoke_bedrock_model(prompt, max_tokens=1000)
        content = response_text.strip()
        
        # Extract JSON from response
        if '{' in content and '}' in content:
            start = content.index('{')
            end = content.rindex('}') + 1
            content = content[start:end]
        
        scores = json.loads(content)
        return scores
    except Exception as e:
        print(f"Error scoring news: {e}")
        return {
            "sentiment_score": 5,
            "likelihood_score": 5,
            "impact_score": 5,
            "explanation": "Error occurred during scoring"
        }


def score_all_news(news_items: List[Dict], ticker: str) -> List[Dict]:
    """
    Score all news items using Amazon Bedrock.
    
    Args:
        news_items: List of news items
        ticker: Stock ticker symbol
    
    Returns:
        List of news items with scores added
    """
    print("\nScoring news items with Amazon Bedrock AI...")
    
    for i, item in enumerate(news_items):
        print(f"Scoring news {i+1}/{len(news_items)}...")
        scores = score_news_item(item, ticker)
        item['scores'] = scores
        time.sleep(1)  # Rate limiting
    
    print("Scoring complete!")
    return news_items

# %%
# Score all news
# scored_news = score_all_news(news_with_content, STOCK_TICKER)
# Out:
# Scoring news items with Amazon Bedrock AI...
# Scoring news 1/10...
# Scoring news 2/10...
# Scoring news 3/10...
# Scoring news 4/10...
# Scoring news 5/10...
# Scoring news 6/10...
# Scoring news 7/10...
# Scoring news 8/10...
# Scoring news 9/10...
# Scoring news 10/10...
# Scoring complete!

# %% [markdown]
# ## 9. Display Results

# %%
def display_scored_news(news_items: List[Dict]):
    """
    Display scored news in a formatted way.
    """
    print("\n" + "="*100)
    print(f"STOCK NEWS ANALYSIS FOR {STOCK_TICKER}")
    print("="*100 + "\n")
    
    for i, item in enumerate(news_items):
        scores = item.get('scores', {})
        
        print(f"\n{'='*100}")
        print(f"NEWS #{i+1}")
        print(f"{'='*100}")
        print(f"\nTitle: {item['title']}")
        print(f"Publisher: {item['publisher']}")
        print(f"Date: {item['report_date']}")
        print(f"Link: {item['link']}")
        print(f"\n{'─'*100}")
        print("SCORES:")
        print(f"{'─'*100}")
        
        sentiment = scores.get('sentiment_score', 5)
        likelihood = scores.get('likelihood_score', 5)
        impact = scores.get('impact_score', 5)
        
        sentiment_label = 'Negative' if sentiment < 4 else 'Neutral' if sentiment <= 6 else 'Positive'
        likelihood_label = 'Speculation' if likelihood < 4 else 'Probable' if likelihood <= 7 else 'Confirmed'
        impact_label = 'Low Impact' if impact < 4 else 'Moderate' if impact <= 6 else 'High Impact'
        
        print(f"  📊 Sentiment Score:   {sentiment}/10  ({sentiment_label})")
        print(f"  🎯 Likelihood Score:  {likelihood}/10  ({likelihood_label})")
        print(f"  💥 Impact Score:      {impact}/10  ({impact_label})")
        print(f"\n  Explanation: {scores.get('explanation', 'N/A')}")
        print()

# display_scored_news(scored_news)
# Out:
# ====================================================================================================
# STOCK NEWS ANALYSIS FOR AAPL
# ====================================================================================================
#
#
# ====================================================================================================
# NEWS #1
# ====================================================================================================
#
# Title: Apple Jumps 5.1% After $100 Billion U.S. Manufacturing Pledge
# Publisher: Zacks
# Date: 2025-08-07
# Link: https://finance.yahoo.com/news/apple-jumps-5-1-100-121100958.html
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# SCORES:
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#   📊 Sentiment Score:   8/10  (Positive)
#   🎯 Likelihood Score:  10/10  (Confirmed)
#   💥 Impact Score:      7/10  (High Impact)
#
#   Explanation: The $100B manufacturing commitment demonstrates strong confidence in US operations and likely appeals to both investors and policymakers. The 5.1% stock jump shows immediate positive market reaction. The large investment signals long-term growth plans while potentially reducing geopolitical risks associated with overseas manufacturing.
#
#
# ====================================================================================================
# NEWS #2
# ====================================================================================================
#
# Title: Apple announces additional $100 billion in US investment, following Trump iPhone tariff threat
# Publisher: Yahoo Finance
# Date: 2025-08-07
# Link: https://finance.yahoo.com/news/apple-announces-additional-100-billion-in-us-investment-following-trump-iphone-tariff-threat-210803143.html
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# SCORES:
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#   📊 Sentiment Score:   7/10  (Positive)
#   🎯 Likelihood Score:  8/10  (Confirmed)
#   💥 Impact Score:      8/10  (High Impact)
#
#   Explanation: A $100B US investment commitment is a significant positive signal for Apple's domestic operations and could help mitigate political/tariff risks. The move appears to be a strategic response to tariff threats, suggesting high likelihood of implementation. The scale of investment and potential tariff avoidance would have substantial impact on Apple's operations and stock valuation.
#
#
# ====================================================================================================
# NEWS #3
# ====================================================================================================
#
# Title: Apple Raises US Investment to $600 Billion as Trump Eyes 100% Chip Tariffs
# Publisher: MT Newswires
# Date: 2025-08-07
# Link: https://finance.yahoo.com/news/apple-raises-us-investment-600-104108645.html
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# SCORES:
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#   📊 Sentiment Score:   6/10  (Neutral)
#   🎯 Likelihood Score:  8/10  (Confirmed)
#   💥 Impact Score:      7/10  (High Impact)
#
#   Explanation: The increased US investment by Apple ($600B) is a positive signal showing strong domestic commitment, though partially offset by potential negative impact from Trump's proposed chip tariffs. The investment amount appears concrete while the tariffs are still speculative. This combination of factors would likely have a significant impact on AAPL's stock price given the scale of investment and potential tariff implications.
#
#
# ====================================================================================================
# NEWS #4
# ====================================================================================================
#
# Title: Apple Announces $100 Billion US Investment Ahead of Trump Event
# Publisher: Bloomberg
# Date: 2025-08-07
# Link: https://finance.yahoo.com/news/trump-apple-announce-fresh-100-130329501.html
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# SCORES:
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#   📊 Sentiment Score:   8/10  (Positive)
#   🎯 Likelihood Score:  7/10  (Probable)
#   💥 Impact Score:      7/10  (High Impact)
#
#   Explanation: A $100B US investment announcement is highly positive for AAPL's public image and long-term growth prospects in its key market. The timing ahead of a Trump event suggests political positioning, which could help secure favorable policy treatment. The large investment size and domestic focus should resonate well with investors and potentially drive stock appreciation.
#
#
# ====================================================================================================
# NEWS #5
# ====================================================================================================
#
# Title: Apple Stock Rallies on Trump’s Plan for ‘Make in America’ Tariff Exemptions
# Publisher: The Wall Street Journal
# Date: 2025-08-08
# Link: https://finance.yahoo.com/m/1c152b80-e9f6-3122-8aeb-0682cfaabde9/apple-stock-rallies-on.html
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# SCORES:
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#   📊 Sentiment Score:   8/10  (Positive)
#   🎯 Likelihood Score:  5/10  (Probable)
#   💥 Impact Score:      7/10  (High Impact)
#
#   Explanation: Potential tariff exemptions would significantly reduce Apple's manufacturing costs and protect their margins on products made in China. However, this is still a plan/proposal rather than confirmed policy, and depends on future political outcomes. The market's positive reaction indicates investors view this as a major potential catalyst for Apple's business model.
#
#
# ====================================================================================================
# NEWS #6
# ====================================================================================================
#
# Title: Apple's $600 Billion U.S. Investment Could Reshape Its Future
# Publisher: Motley Fool
# Date: 2025-08-10
# Link: https://finance.yahoo.com/m/a4fd4c66-a9bf-369a-9dda-cb171d9ad99e/apple%27s-%24600-billion-u.s..html
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# SCORES:
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#   📊 Sentiment Score:   8/10  (Positive)
#   🎯 Likelihood Score:  5/10  (Probable)
#   💥 Impact Score:      7/10  (High Impact)
#
#   Explanation: A $600B US investment would be highly positive for Apple's long-term growth and domestic manufacturing capabilities, though the amount is very large even for Apple's cash reserves. Such a massive investment would significantly impact Apple's future operations and stock valuation, but the likelihood score is moderate since this appears to be a forward-looking announcement rather than a completed action.
#
#
# ====================================================================================================
# NEWS #7
# ====================================================================================================
#
# Title: Apple announces five-year partnership as U.S. broadcast partner for Formula 1
# Publisher: TipRanks
# Date: 2025-10-18
# Link: https://finance.yahoo.com/m/aa6d4ee1-1bb9-3678-93a2-ff1d2e359744/apple-announces-five-year.html
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# SCORES:
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#   📊 Sentiment Score:   7/10  (Positive)
#   🎯 Likelihood Score:  10/10  (Confirmed)
#   💥 Impact Score:      4/10  (Moderate)
#
#   Explanation: This partnership represents a positive move for Apple as it expands its sports content portfolio and strengthens Apple TV+'s offerings. While Formula 1 has growing popularity in the US, the financial impact is relatively modest compared to Apple's overall revenue streams. The deal is confirmed and official, hence the high likelihood score.
#
#
# ====================================================================================================
# NEWS #8
# ====================================================================================================
#
# Title: Apple (AAPL) Q4 Earnings and Revenues Beat Estimates
# Publisher: Zacks
# Date: 2025-10-31
# Link: https://finance.yahoo.com/news/apple-aapl-q4-earnings-revenues-214002311.html
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# SCORES:
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#   📊 Sentiment Score:   8/10  (Positive)
#   🎯 Likelihood Score:  10/10  (Confirmed)
#   💥 Impact Score:      7/10  (High Impact)
#
#   Explanation: Beating both earnings and revenue estimates is strongly positive for Apple's stock as it demonstrates the company's continued financial strength and ability to exceed market expectations. The news is confirmed earnings data so likelihood is certain. The impact is significant as earnings reports typically drive major stock price movements, though the market may have partially priced in positive results.
#
#
# ====================================================================================================
# NEWS #9
# ====================================================================================================
#
# Title: Market Chatter: Globalstar Explores Sale, Holds Early Talks With SpaceX
# Publisher: MT Newswires
# Date: 2025-10-31
# Link: https://finance.yahoo.com/news/market-chatter-globalstar-explores-sale-192320412.html
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# SCORES:
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#   📊 Sentiment Score:   4/10  (Neutral)
#   🎯 Likelihood Score:  3/10  (Speculation)
#   💥 Impact Score:      3/10  (Low Impact)
#
#   Explanation: While Globalstar is Apple's satellite partner for Emergency SOS, a potential sale to SpaceX could create uncertainty around this partnership. The news is still in early speculation phase with only preliminary talks reported. The impact on Apple would be limited since satellite features are not a core revenue driver for the company.
#
#
# ====================================================================================================
# NEWS #10
# ====================================================================================================
#
# Title: Heard on the Street Recap: Market Streak
# Publisher: The Wall Street Journal
# Date: 2025-11-01
# Link: https://finance.yahoo.com/m/c56c6928-c549-3d23-81f5-aeac70568e0a/heard-on-the-street-recap%3A.html
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# SCORES:
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#   📊 Sentiment Score:   5/10  (Neutral)
#   🎯 Likelihood Score:  5/10  (Probable)
#   💥 Impact Score:      0/10  (Low Impact)
#
#   Explanation: The title alone provides insufficient information to make any meaningful assessment about AAPL specifically. Without actual content about Apple in the article, there's no basis to determine sentiment or impact on the stock.

# %% [markdown]
# ## 10. Create Summary DataFrame

# %%
# Create a DataFrame for easy analysis
# summary_data = []
# for item in scored_news:
#     scores = item.get('scores', {})
#     summary_data.append({
#         'Title': item['title'][:80] + '...' if len(item['title']) > 80 else item['title'],
#         'Date': item['report_date'],
#         'Publisher': item['publisher'],
#         'Sentiment': scores.get('sentiment_score', 'N/A'),
#         'Likelihood': scores.get('likelihood_score', 'N/A'),
#         'Impact': scores.get('impact_score', 'N/A'),
#         'Link': item['link']
#     })

# df = pd.DataFrame(summary_data)
# print("\nSummary DataFrame:")
# df
# Out:
# Summary DataFrame:
#                                                Title        Date  \
# 0  Apple Jumps 5.1% After $100 Billion U.S. Manuf...  2025-08-07
# 1  Apple announces additional $100 billion in US ...  2025-08-07
# 2  Apple Raises US Investment to $600 Billion as ...  2025-08-07
# 3  Apple Announces $100 Billion US Investment Ahe...  2025-08-07
# 4  Apple Stock Rallies on Trump’s Plan for ‘Make ...  2025-08-08
# 5  Apple's $600 Billion U.S. Investment Could Res...  2025-08-10
# 6  Apple announces five-year partnership as U.S. ...  2025-10-18
# 7  Apple (AAPL) Q4 Earnings and Revenues Beat Est...  2025-10-31
# 8  Market Chatter: Globalstar Explores Sale, Hold...  2025-10-31
# 9           Heard on the Street Recap: Market Streak  2025-11-01
#
#                  Publisher  Sentiment  Likelihood  Impact  \
# 0                    Zacks          8          10       7
# 1            Yahoo Finance          7           8       8
# 2             MT Newswires          6           8       7
# 3                Bloomberg          8           7       7
# 4  The Wall Street Journal          8           5       7
# 5              Motley Fool          8           5       7
# 6                 TipRanks          7          10       4
# 7                    Zacks          8          10       7
# 8             MT Newswires          4           3       3
# 9  The Wall Street Journal          5           5       0
#
#                                                 Link
# 0  https://finance.yahoo.com/news/apple-jumps-5-1...
# 1  https://finance.yahoo.com/news/apple-announces...
# 2  https://finance.yahoo.com/news/apple-raises-us...
# 3  https://finance.yahoo.com/news/trump-apple-ann...
# 4  https://finance.yahoo.com/m/1c152b80-e9f6-3122...
# 5  https://finance.yahoo.com/m/a4fd4c66-a9bf-369a...
# 6  https://finance.yahoo.com/m/aa6d4ee1-1bb9-3678...
# 7  https://finance.yahoo.com/news/apple-aapl-q4-e...
# 8  https://finance.yahoo.com/news/market-chatter-...
# 9  https://finance.yahoo.com/m/c56c6928-c549-3d23...

# %% [markdown]
# ## 11. Combined Analysis Function

# %%
def analyze_stock_news(ticker: str) -> List[Dict]:
    """
    Analyze stock news for a given ticker and return formatted results.
    
    Args:
        ticker: Stock ticker symbol
    
    Returns:
        List of dictionaries with news analysis
    """
    TOP_N_NEWS = 10
    MONTHS_BACK = 3
    
    # Fetch news
    news_items = get_stock_news(ticker, months_back=MONTHS_BACK)
    
    # Select interesting news
    interesting_news = select_interesting_news(news_items, ticker, top_n=TOP_N_NEWS)
    
    # Fetch full content
    news_with_content = fetch_news_content(ticker, interesting_news)
    
    # Score all news
    scored_news = score_all_news(news_with_content, ticker)
    
    # Format output
    result = []
    for item in scored_news:
        scores = item.get('scores', {})
        result.append({
            "nom": item['title'],
            "score": scores.get('sentiment_score', 5) / 2,
            "résumé": scores.get('explanation', ''),
            "lien": item['link'],
            "confiance": scores.get('likelihood_score', 5) / 2
        })
    
    return result

# %%
# Test the combined function
# result = analyze_stock_news(STOCK_TICKER)
# print("Analysis complete! Here's the formatted output:")
# import json
# print(json.dumps(result, indent=2, ensure_ascii=False))
# Out:
# Fetching news for AAPL...
# Found 894 news items from the last 3 months
#
# Using Amazon Bedrock AI to select top 10 most interesting news items...
# Selected 10 news items
#
# Fetching full content for selected news...
# Fetching content 1/10...
# Fetching content 2/10...
# Fetching content 3/10...
# Fetching content 4/10...
# Fetching content 5/10...
# Fetching content 6/10...
# Fetching content 7/10...
# Fetching content 8/10...
# Fetching content 9/10...
# Fetching content 10/10...
# Content fetching complete!
#
# Scoring news items with Amazon Bedrock AI...
# Scoring news 1/10...
# Scoring news 2/10...
# Scoring news 3/10...
# Scoring news 4/10...
# Scoring news 5/10...
# Scoring news 6/10...
# Scoring news 7/10...
# Scoring news 8/10...
# Scoring news 9/10...
# Scoring news 10/10...
# Scoring complete!
# Analysis complete! Here's the formatted output:
# [
#   {
#     "nom": "Apple announces additional $100 billion in US investment, following Trump iPhone tariff threat",
#     "score": 3.5,
#     "résumé": "A $100B US investment commitment is significantly positive for AAPL's public image and domestic operations, though partially offset by the defensive nature of the announcement in response to tariff threats. The likelihood is high given it's a formal announcement, and the impact is substantial as it affects both manufacturing strategy and capital allocation while potentially mitigating political/tariff risks.",
#     "lien": "https://finance.yahoo.com/news/apple-announces-additional-100-billion-in-us-investment-following-trump-iphone-tariff-threat-210803143.html",
#     "confiance": 4.0
#   },
#   {
#     "nom": "Apple Raises US Investment to $600 Billion as Trump Eyes 100% Chip Tariffs",
#     "score": 3.0,
#     "résumé": "The increased US investment by Apple ($600B) is a positive signal showing commitment to domestic operations, though partially offset by potential negative impact from Trump's proposed chip tariffs. The investment amount appears concrete while the tariffs are still speculative. This combination of factors would likely have a significant impact on Apple's operations and stock price given the scale of investment and potential tariff implications.",
#     "lien": "https://finance.yahoo.com/news/apple-raises-us-investment-600-104108645.html",
#     "confiance": 4.0
#   },
#   {
#     "nom": "Apple Shows How to Avoid Trump Tariff Pain. Why It’s Not Great for Stock Markets and 4 Other Things to Know Today.",
#     "score": 3.0,
#     "résumé": "The news suggests Apple has found ways to mitigate potential tariff impacts, which is moderately positive for the company's cost management. While tariff avoidance is beneficial for Apple's margins, the broader market implications could create some offsetting headwinds. The high likelihood score reflects that this appears to be reporting on existing strategies rather than speculation.",
#     "lien": "https://finance.yahoo.com/m/e08550ce-ed7b-36c6-8749-d7a654e7405e/apple-shows-how-to-avoid.html",
#     "confiance": 4.0
#   },
#   {
#     "nom": "JPMorgan says Apple delivered ’masterclass’ in managing geopolitics",
#     "score": 4.0,
#     "résumé": "JPMorgan's positive assessment of Apple's geopolitical management capabilities is a strong endorsement from a major financial institution, suggesting reduced risk in Apple's global operations. The analysis is based on observed events, making it highly credible. While important for long-term stability, geopolitical management typically has a moderate rather than dramatic immediate impact on stock price.",
#     "lien": "https://finance.yahoo.com/news/jpmorgan-says-apple-delivered-masterclass-124112515.html",
#     "confiance": 5.0
#   },
#   {
#     "nom": "Apple Jumps 5.1% After $100 Billion U.S. Manufacturing Pledge",
#     "score": 4.0,
#     "résumé": "A $100B manufacturing commitment to U.S. operations is a significant positive signal for both investor confidence and government relations. The 5.1% stock jump confirms strong market approval, and the news is already verified as happening. The impact is substantial but not transformative given Apple's overall market cap and existing manufacturing footprint.",
#     "lien": "https://finance.yahoo.com/news/apple-jumps-5-1-100-121100958.html",
#     "confiance": 5.0
#   },
#   {
#     "nom": "Apple's New $100 Billion US Investment, Manufacturing Program May Shield Products From Tariffs, BofA Says",
#     "score": 4.0,
#     "résumé": "A $100B US investment program would significantly reduce Apple's exposure to tariff risks and strengthen its domestic manufacturing presence. Coming from a credible source (BofA) and being a substantial investment amount, this news suggests a strong positive strategic move. The potential tariff protection and domestic manufacturing expansion would have meaningful impact on Apple's operational costs and market position.",
#     "lien": "https://finance.yahoo.com/news/apple-apos-100-billion-us-153438082.html",
#     "confiance": 3.5
#   },
#   {
#     "nom": "Apple is back on Trump's good side. The cost? $600 billion.",
#     "score": 3.0,
#     "résumé": "Having Trump's support could reduce political/regulatory risks for Apple and potentially help with US-China trade relations. The $600B cost mentioned is concerning but appears to be a negotiated arrangement rather than a penalty. Political alignment with a potential presidential candidate could provide stability for Apple's operations.",
#     "lien": "https://finance.yahoo.com/news/apple-is-back-on-trumps-good-side-the-cost-600-billion-113413035.html",
#     "confiance": 4.0
#   },
#   {
#     "nom": "Apple (AAPL) Q4 Earnings and Revenues Beat Estimates",
#     "score": 4.0,
#     "résumé": "Beating both earnings and revenue estimates is strongly positive for Apple's stock, indicating strong business performance. This is confirmed earnings data, not speculation. Quarterly earnings beats typically have significant impact on stock price movement, though the impact may be moderated if the beats were already partially priced in.",
#     "lien": "https://finance.yahoo.com/news/apple-aapl-q4-earnings-revenues-214002311.html",
#     "confiance": 5.0
#   },
#   {
#     "nom": "How Tim Cook Evaded Disaster at Apple This Year",
#     "score": 3.5,
#     "résumé": "The headline suggests Tim Cook successfully navigated through challenges at Apple, which is positive for investor confidence. The use of 'evaded disaster' indicates there were serious risks that were effectively managed, showing strong leadership. The fact that this is a retrospective piece from WSJ about events that already occurred gives it high credibility.",
#     "lien": "https://finance.yahoo.com/m/ed110364-fe80-3d13-a7f5-59dfcd7154f3/how-tim-cook-evaded-disaster.html",
#     "confiance": 5.0
#   },
#   {
#     "nom": "Apple in talks to use Google's Gemini AI to power revamped Siri, Bloomberg News reports",
#     "score": 3.5,
#     "résumé": "Apple partnering with Google for AI technology would be a significant strategic move to catch up in the AI race, potentially transforming Siri into a more competitive assistant. While this is still in talks, Bloomberg's reporting typically has credibility. This could have a major impact on Apple's competitive position in AI and its stock price, as AI capabilities are currently a key driver of tech valuations.",
#     "lien": "https://finance.yahoo.com/news/apple-talks-googles-gemini-ai-172230223.html",
#     "confiance": 3.0
#   }
# ]
