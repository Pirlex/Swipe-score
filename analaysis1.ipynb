# %%
import sys
# !{sys.executable} -m pip install yfinance sec-parser
# Out:
# Collecting yfinance
#   Using cached yfinance-0.2.66-py2.py3-none-any.whl.metadata (6.0 kB)
# Collecting sec-parser
#   Using cached sec_parser-0.58.1-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: pandas>=1.3.0 in /opt/conda/lib/python3.11/site-packages (from yfinance) (2.3.3)
# Requirement already satisfied: numpy>=1.16.5 in /opt/conda/lib/python3.11/site-packages (from yfinance) (2.3.4)
# Requirement already satisfied: requests>=2.31 in /opt/conda/lib/python3.11/site-packages (from yfinance) (2.32.5)
# Collecting sec-parser
#   Using cached sec_parser-0.58.1-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: pandas>=1.3.0 in /opt/conda/lib/python3.11/site-packages (from yfinance) (2.3.3)
# Requirement already satisfied: numpy>=1.16.5 in /opt/conda/lib/python3.11/site-packages (from yfinance) (2.3.4)
# Requirement already satisfied: requests>=2.31 in /opt/conda/lib/python3.11/site-packages (from yfinance) (2.32.5)
# Collecting multitasking>=0.0.7 (from yfinance)
#   Using cached multitasking-0.0.12-py3-none-any.whl
# Requirement already satisfied: platformdirs>=2.0.0 in /opt/conda/lib/python3.11/site-packages (from yfinance) (4.5.0)
# Requirement already satisfied: pytz>=2022.5 in /opt/conda/lib/python3.11/site-packages (from yfinance) (2024.2)
# Requirement already satisfied: frozendict>=2.3.4 in /opt/conda/lib/python3.11/site-packages (from yfinance) (2.4.6)
# Collecting peewee>=3.16.2 (from yfinance)
#   Using cached peewee-3.18.2-cp311-cp311-linux_x86_64.whl
# Collecting multitasking>=0.0.7 (from yfinance)
#   Using cached multitasking-0.0.12-py3-none-any.whl
# Requirement already satisfied: platformdirs>=2.0.0 in /opt/conda/lib/python3.11/site-packages (from yfinance) (4.5.0)
# Requirement already satisfied: pytz>=2022.5 in /opt/conda/lib/python3.11/site-packages (from yfinance) (2024.2)
# Requirement already satisfied: frozendict>=2.3.4 in /opt/conda/lib/python3.11/site-packages (from yfinance) (2.4.6)
# Collecting peewee>=3.16.2 (from yfinance)
#   Using cached peewee-3.18.2-cp311-cp311-linux_x86_64.whl
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /opt/conda/lib/python3.11/site-packages (from yfinance) (4.14.2)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /opt/conda/lib/python3.11/site-packages (from yfinance) (4.14.2)
# Collecting curl_cffi>=0.7 (from yfinance)
#   Using cached curl_cffi-0.13.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: protobuf>=3.19.0 in /opt/conda/lib/python3.11/site-packages (from yfinance) (5.28.3)
# Requirement already satisfied: websockets>=13.0 in /opt/conda/lib/python3.11/site-packages (from yfinance) (15.0.1)
# Collecting curl_cffi>=0.7 (from yfinance)
#   Using cached curl_cffi-0.13.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: protobuf>=3.19.0 in /opt/conda/lib/python3.11/site-packages (from yfinance) (5.28.3)
# Requirement already satisfied: websockets>=13.0 in /opt/conda/lib/python3.11/site-packages (from yfinance) (15.0.1)
# Collecting cssutils<3.0.0,>=2.11.1 (from sec-parser)
#   Using cached cssutils-2.11.1-py3-none-any.whl.metadata (8.7 kB)
# Collecting cssutils<3.0.0,>=2.11.1 (from sec-parser)
#   Using cached cssutils-2.11.1-py3-none-any.whl.metadata (8.7 kB)
# Collecting loguru<0.8.0,>=0.7.2 (from sec-parser)
#   Using cached loguru-0.7.3-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: lxml<6.0.0,>=5.2.2 in /opt/conda/lib/python3.11/site-packages (from sec-parser) (5.4.0)
# Collecting loguru<0.8.0,>=0.7.2 (from sec-parser)
#   Using cached loguru-0.7.3-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: lxml<6.0.0,>=5.2.2 in /opt/conda/lib/python3.11/site-packages (from sec-parser) (5.4.0)
# Collecting sec-downloader<0.12.0,>=0.11.1 (from sec-parser)
#   Using cached sec_downloader-0.11.2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: tabulate<0.10.0,>=0.9.0 in /opt/conda/lib/python3.11/site-packages (from sec-parser) (0.9.0)
# Requirement already satisfied: xxhash<4.0.0,>=3.4.1 in /opt/conda/lib/python3.11/site-packages (from sec-parser) (3.6.0)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.11/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /opt/conda/lib/python3.11/site-packages (from beautifulsoup4>=4.11.1->yfinance) (4.15.0)
# Collecting sec-downloader<0.12.0,>=0.11.1 (from sec-parser)
#   Using cached sec_downloader-0.11.2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: tabulate<0.10.0,>=0.9.0 in /opt/conda/lib/python3.11/site-packages (from sec-parser) (0.9.0)
# Requirement already satisfied: xxhash<4.0.0,>=3.4.1 in /opt/conda/lib/python3.11/site-packages (from sec-parser) (3.6.0)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.11/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /opt/conda/lib/python3.11/site-packages (from beautifulsoup4>=4.11.1->yfinance) (4.15.0)
# Collecting more-itertools (from cssutils<3.0.0,>=2.11.1->sec-parser)
#   Using cached more_itertools-10.8.0-py3-none-any.whl.metadata (39 kB)
# Requirement already satisfied: cffi>=1.12.0 in /opt/conda/lib/python3.11/site-packages (from curl_cffi>=0.7->yfinance) (1.17.1)
# Requirement already satisfied: certifi>=2024.2.2 in /opt/conda/lib/python3.11/site-packages (from curl_cffi>=0.7->yfinance) (2025.10.5)
# Collecting more-itertools (from cssutils<3.0.0,>=2.11.1->sec-parser)
#   Using cached more_itertools-10.8.0-py3-none-any.whl.metadata (39 kB)
# Requirement already satisfied: cffi>=1.12.0 in /opt/conda/lib/python3.11/site-packages (from curl_cffi>=0.7->yfinance) (1.17.1)
# Requirement already satisfied: certifi>=2024.2.2 in /opt/conda/lib/python3.11/site-packages (from curl_cffi>=0.7->yfinance) (2025.10.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.11/site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.11/site-packages (from pandas>=1.3.0->yfinance) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests>=2.31->yfinance) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests>=2.31->yfinance) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests>=2.31->yfinance) (2.5.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.11/site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.11/site-packages (from pandas>=1.3.0->yfinance) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests>=2.31->yfinance) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests>=2.31->yfinance) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests>=2.31->yfinance) (2.5.0)
# Collecting sec-edgar-downloader (from sec-downloader<0.12.0,>=0.11.1->sec-parser)
#   Using cached sec_edgar_downloader-5.0.3-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.11/site-packages (from cffi>=1.12.0->curl_cffi>=0.7->yfinance) (2.22)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)
# Collecting sec-edgar-downloader (from sec-downloader<0.12.0,>=0.11.1->sec-parser)
#   Using cached sec_edgar_downloader-5.0.3-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.11/site-packages (from cffi>=1.12.0->curl_cffi>=0.7->yfinance) (2.22)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)
# Collecting pyrate-limiter>=3.6.0 (from sec-edgar-downloader->sec-downloader<0.12.0,>=0.11.1->sec-parser)
#   Using cached pyrate_limiter-3.9.0-py3-none-any.whl.metadata (28 kB)
# Using cached yfinance-0.2.66-py2.py3-none-any.whl (123 kB)
# Using cached sec_parser-0.58.1-py3-none-any.whl (76 kB)
# Using cached cssutils-2.11.1-py3-none-any.whl (385 kB)
# Using cached curl_cffi-0.13.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.3 MB)
# Collecting pyrate-limiter>=3.6.0 (from sec-edgar-downloader->sec-downloader<0.12.0,>=0.11.1->sec-parser)
#   Using cached pyrate_limiter-3.9.0-py3-none-any.whl.metadata (28 kB)
# Using cached yfinance-0.2.66-py2.py3-none-any.whl (123 kB)
# Using cached sec_parser-0.58.1-py3-none-any.whl (76 kB)
# Using cached cssutils-2.11.1-py3-none-any.whl (385 kB)
# Using cached curl_cffi-0.13.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.3 MB)
# Using cached loguru-0.7.3-py3-none-any.whl (61 kB)
# Using cached sec_downloader-0.11.2-py3-none-any.whl (11 kB)
# Using cached more_itertools-10.8.0-py3-none-any.whl (69 kB)
# Using cached sec_edgar_downloader-5.0.3-py3-none-any.whl (14 kB)
# Using cached pyrate_limiter-3.9.0-py3-none-any.whl (33 kB)
# Using cached loguru-0.7.3-py3-none-any.whl (61 kB)
# Using cached sec_downloader-0.11.2-py3-none-any.whl (11 kB)
# Using cached more_itertools-10.8.0-py3-none-any.whl (69 kB)
# Using cached sec_edgar_downloader-5.0.3-py3-none-any.whl (14 kB)
# Using cached pyrate_limiter-3.9.0-py3-none-any.whl (33 kB)
# Installing collected packages: peewee, multitasking, pyrate-limiter, more-itertools, loguru, sec-edgar-downloader, curl_cffi, cssutils, yfinance, sec-downloader, sec-parser
# Installing collected packages: peewee, multitasking, pyrate-limiter, more-itertools, loguru, sec-edgar-downloader, curl_cffi, cssutils, yfinance, sec-downloader, sec-parser
# Successfully installed cssutils-2.11.1 curl_cffi-0.13.0 loguru-0.7.3 more-itertools-10.8.0 multitasking-0.0.12 peewee-3.18.2 pyrate-limiter-3.9.0 sec-downloader-0.11.2 sec-edgar-downloader-5.0.3 sec-parser-0.58.1 yfinance-0.2.66
# Successfully installed cssutils-2.11.1 curl_cffi-0.13.0 loguru-0.7.3 more-itertools-10.8.0 multitasking-0.0.12 peewee-3.18.2 pyrate-limiter-3.9.0 sec-downloader-0.11.2 sec-edgar-downloader-5.0.3 sec-parser-0.58.1 yfinance-0.2.66

# %%
from typing import TypedDict


class MetricData(TypedDict):
    volatility: float
    variation: float


# Get the market cap, variation and volatility in % in the last week, month and year about a given stock
def get_stock_data(symbol: str) -> dict:
    import yfinance as yf
    import numpy as np
    from datetime import datetime, timedelta, timezone

    continent_map = {
        'United States': 'North America',
        'USA': 'North America',
        # Add more mappings as needed
    }

    stock = yf.Ticker(symbol)
    info = stock.info
    cap = info.get('marketCap')
    recommendation = info.get('recommendationKey')
    
    # Map recommendation to indicator out of 5
    recommendation_map = {
        'STRONG_BUY': 5,
        'BUY': 4,
        'HOLD': 3,
        'SELL': 2,
        'STRONG_SELL': 1
    }
    indicator = recommendation_map.get(recommendation.upper() if recommendation else None, None)
    
    results = {'cap': cap, 'yahoo_pespective': indicator}
    results['stock_exchange'] = info.get('exchange')
    results['country'] = info.get('country')
    results['sector'] = info.get('sector')
    results['industry'] = info.get('industry')
    results['continent'] = continent_map.get(results['country'], 'Unknown')
    
    end_date = datetime.now(timezone.utc)

    periods = {
        '1w': end_date - timedelta(weeks=1),
        '1m': end_date - timedelta(days=30),
        '1y': end_date - timedelta(days=365)
    }

    for period, start_date in periods.items():
        hist = stock.history(start=start_date.strftime('%Y-%m-%d'), end=end_date.strftime('%Y-%m-%d'))
        if len(hist) < 2:
            results[f'variation_{period}'] = None
            results[f'volatility_{period}'] = None
            continue

        returns = hist['Close'].pct_change().dropna()
        volatility = returns.std() * np.sqrt(252) * 100  # Annualized %
        variation = ((hist['Close'].iloc[-1] - hist['Close'].iloc[0]) / hist['Close'].iloc[0]) * 100

        results[f'variation_{period}'] = round(variation, 2)
        results[f'volatility_{period}'] = round(volatility, 2)
    results['variation'] = float(min(5, max(0, 0.2 * results['variation_1w'] + 0.3 * results['variation_1m'] + 0.5 * results['variation_1y'])))
    results['volatility'] = float(min(5, max(0, 5 - 0.2 * results['volatility_1w'] - 0.3 * results['volatility_1m'] - 0.5 * results['volatility_1y'])))

    return results

# %%
# print(get_stock_data("AAPL"))
# Out:
# {'cap': 3995082424320, 'yahoo_pespective': 4, 'stock_exchange': 'NMS', 'country': 'United States', 'sector': 'Technology', 'industry': 'Consumer Electronics', 'continent': 'North America', 'variation_1w': np.float64(0.58), 'volatility_1w': np.float64(6.67), 'variation_1m': np.float64(5.33), 'volatility_1m': np.float64(25.04), 'variation_1y': np.float64(22.35), 'volatility_1y': np.float64(32.77), 'variation': 5.0, 'volatility': 0.0}
